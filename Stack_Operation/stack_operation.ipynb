# %%
import torch

# %%
tensor1 =torch.tensor([1, 2, 3])
tensor2 =torch.tensor([4, 5, 6])

# %%
stacked_tensor_dim0 = torch.stack((tensor1, tensor2))
print("Shape : ", stacked_tensor_dim0.shape)
print(stacked_tensor_dim0)

print("+"*30)

stacked_tensor_dim1 = torch.stack((tensor1, tensor2))
print("Shape : ", stacked_tensor_dim1.shape)
print(stacked_tensor_dim1)
# Out:
# Shape :  torch.Size([2, 3])
# tensor([[1, 2, 3],
#         [4, 5, 6]])
# ++++++++++++++++++++++++++++++
# Shape :  torch.Size([2, 3])
# tensor([[1, 2, 3],
#         [4, 5, 6]])
