# %%
import torch

# %%
tensor = torch.tensor([[1,2,3],[4,5,6]])
print("Tensor Dimension : ", tensor.ndim)
print("The Shape of Tensor : ", tensor.shape)
# Out:
# Tensor Dimension :  2
# The Shape of Tensor :  torch.Size([2, 3])

# %%
print("row : ", tensor[0,1])
# Out:
# row :  tensor(2)

# %%
print(tensor[0])
# Out:
# tensor([1, 2, 3])

# %%
print(tensor[0, 2])
# Out:
# tensor(3)

# %%
print(tensor[:, :2])
# Out:
# tensor([[1, 2],
#         [4, 5]])

# %%
print(tensor[1 , 1:3])
# Out:
# tensor([5, 6])

# %%
print(tensor)
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
# fancy indexing
# (0,2) --> 3
# (1,0) --> 4

print(tensor[[0,1],[2,0]])
# Out:
# tensor([3, 4])
