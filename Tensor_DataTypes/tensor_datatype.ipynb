# %%
import torch

# %%
default_tensor = torch.tensor([1.2, 2.3, 3.4])
print(default_tensor.dtype)
# Out:
# torch.float32

# %%
tesor_type = torch.tensor([1.2, 2.5, 4.4], dtype=torch.float64)
print(tesor_type.dtype)
# Out:
# torch.float64

# %%
int_tensor = torch.tensor([1.5, 2.7, 3.9], dtype=torch.int32)
print(int_tensor.dtype)
print(int_tensor)
# Out:
# torch.int32
# tensor([1, 2, 3], dtype=torch.int32)

# %%
int_tensor = torch.tensor([1, 2, 3])
print(int_tensor.dtype)
# Out:
# torch.int64

# %%
boolean_tensor = torch.tensor([True, False, True], dtype=torch.bool)
print(boolean_tensor.dtype)
print(boolean_tensor)
# Out:
# torch.bool
# tensor([ True, False,  True])

# %%
boolean_tensor = torch.tensor([True, False, True])
print(boolean_tensor.dtype)
print(boolean_tensor)
# Out:
# torch.bool
# tensor([ True, False,  True])

# %% [markdown]
# # converting Data Type

# %%
float_tensor = torch.tensor([1.2, 2.3, 3.4], dtype=torch.float32)
print(float_tensor.dtype)
print(float_tensor)

int_tensor = float_tensor.to(torch.int32)
print(int_tensor.dtype)
print(int_tensor)

intger_tensor = torch.tensor([1, 2, 3], dtype=torch.int32)

boolean_tensor = intger_tensor.to(torch.bool)
print(boolean_tensor.dtype)
print(boolean_tensor)
# Out:
# torch.float32
# tensor([1.2000, 2.3000, 3.4000])
# torch.int32
# tensor([1, 2, 3], dtype=torch.int32)
# torch.bool
# tensor([True, True, True])

# %%
float32_tensor = torch.ones(1000, dtype=torch.float32)
float64_tensor = torch.ones(1000, dtype=torch.float64)


print(float32_tensor.element_size())
print(float32_tensor.nelement())

print("Memory usage (float32):", float32_tensor.element_size() * float32_tensor.nelement())
print("Memory usage (float64):", float64_tensor.element_size() * float64_tensor.nelement())
# Out:
# 4
# 1000
# Memory usage (float32): 4000
# Memory usage (float64): 8000
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
